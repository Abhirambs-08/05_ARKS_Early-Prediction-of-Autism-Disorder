# %%
import numpy as np
import pandas as pd 
from keras.preprocessing import image
from keras.preprocessing.image import ImageDataGenerator 
from tensorflow.keras.utils import load_img
from keras.utils import to_categorical
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
import random
import os
from keras.optimizers import Adam

# %%
FAST_RUN = False
IMAGE_WIDTH=128
IMAGE_HEIGHT=128
IMAGE_SIZE=(IMAGE_WIDTH, IMAGE_HEIGHT)
IMAGE_CHANNELS=3

# %%
filenames = os.listdir("C:/Users/91809/Desktop/ARKS/05_ARKS_Early-Prediction-of-Autism-Disorder/AutismDataset/train")
categories = []
for filename in filenames:
    category = filename.split('.')[0]
    if category == 'Autistic':
        categories.append(1)
    else:
        categories.append(0)

df = pd.DataFrame({
    'filename': filenames,
    'category': categories
})

# %%
df.head()
# Out:
#             filename  category
# 0     Autistic.0.jpg         1
# 1     Autistic.1.jpg         1
# 2    Autistic.10.jpg         1
# 3   Autistic.100.jpg         1
# 4  Autistic.1000.jpg         1

# %%
df.tail()
# Out:
#                   filename  category
# 2535  Non_Autistic.995.jpg         0
# 2536  Non_Autistic.996.jpg         0
# 2537  Non_Autistic.997.jpg         0
# 2538  Non_Autistic.998.jpg         0
# 2539  Non_Autistic.999.jpg         0

# %%
import os

# Directory path
directory_path = "C:/Users/91809/Desktop/ARKS/05_ARKS_Early-Prediction-of-Autism-Disorder/AutismDataset/train"

# Sample filename
sample = random.choice(filenames)  # Make sure sample contains the filename you want to load

# Create the full file path
file_path = os.path.join(directory_path, sample)

# Now load the image
image = load_img(file_path)

# %%
plt.imshow(image)

# %%
# CNN model
from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D, Dropout, Flatten, Dense, Activation, BatchNormalization

model = Sequential()

model.add(Conv2D(32, (3, 3), activation='relu', input_shape=(IMAGE_WIDTH, IMAGE_HEIGHT, IMAGE_CHANNELS)))
model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.25))

model.add(Conv2D(64, (3, 3), activation='relu'))
model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.25))

model.add(Conv2D(128, (3, 3), activation='relu'))
model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.25))

model.add(Flatten())
model.add(Dense(512, activation='relu'))
model.add(BatchNormalization())
model.add(Dropout(0.5))
model.add(Dense(2, activation='softmax')) 
optimizer = Adam(lr = 0.0001)
model.compile(loss='categorical_crossentropy', optimizer='rmsprop', metrics=['accuracy'])

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 126, 126, 32)      896
#
#  batch_normalization (BatchN  (None, 126, 126, 32)     128
#  ormalization)
#
#  max_pooling2d (MaxPooling2D  (None, 63, 63, 32)       0
#  )
#
#  dropout (Dropout)           (None, 63, 63, 32)        0
#
#  conv2d_1 (Conv2D)           (None, 61, 61, 64)        18496
#
#  batch_normalization_1 (Batc  (None, 61, 61, 64)       256
#  hNormalization)
#
#  max_pooling2d_1 (MaxPooling  (None, 30, 30, 64)       0
#  2D)
#
#  dropout_1 (Dropout)         (None, 30, 30, 64)        0
#
#  conv2d_2 (Conv2D)           (None, 28, 28, 128)       73856
#
#  batch_normalization_2 (Batc  (None, 28, 28, 128)      512
#  hNormalization)
#
#  max_pooling2d_2 (MaxPooling  (None, 14, 14, 128)      0
#  2D)
#
#  dropout_2 (Dropout)         (None, 14, 14, 128)       0
#
#  flatten (Flatten)           (None, 25088)             0
#
#  dense (Dense)               (None, 512)               12845568
#
#  batch_normalization_3 (Batc  (None, 512)              2048
#  hNormalization)
#
#  dropout_3 (Dropout)         (None, 512)               0
#
#  dense_1 (Dense)             (None, 2)                 1026
#
# =================================================================
# Total params: 12,942,786
# Trainable params: 12,941,314
# Non-trainable params: 1,472
# _________________________________________________________________
# C:\ProgramData\anaconda3\lib\site-packages\keras\optimizers\optimizer_v2\adam.py:114: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super().__init__(name, **kwargs)

# %%
from keras.callbacks import EarlyStopping, ReduceLROnPlateau

# %%
# patience value
earlystop = EarlyStopping(patience=50)

# %%
learning_rate_reduction = ReduceLROnPlateau(monitor='val_acc', 
                                            patience=2, 
                                            verbose=1, 
                                            factor=0.5, 
                                            min_lr=0.00001)

# %%
callbacks = [earlystop, learning_rate_reduction]

# %%
# Data preparation for training
df["category"] = df["category"].replace({0: 'Non_Autistic', 1: 'Autistic'})

# %%
# 80:20 ratio
train_df, validate_df = train_test_split(df, test_size=0.20, random_state=42)
train_df = train_df.reset_index(drop=True)
validate_df = validate_df.reset_index(drop=True)

# %%
train_df['category'].value_counts().plot.bar()
# Out:
# <Axes: >

# %%
validate_df['category'].value_counts().plot.bar()
# Out:
# <Axes: >

# %%
total_train = train_df.shape[0]
total_validate = validate_df.shape[0]
batch_size=32

# %%
# Training Generator
train_datagen = ImageDataGenerator(
    rotation_range=10,
    rescale=1./255,
    shear_range=0.1,
    zoom_range=0.2,
    horizontal_flip=True,
    width_shift_range=0.1,
    height_shift_range=0.1
)

train_generator = train_datagen.flow_from_dataframe(
    train_df, 
    "C:/Users/91809/Desktop/ARKS/05_ARKS_Early-Prediction-of-Autism-Disorder/AutismDataset/train", 
    x_col='filename',
    y_col='category',
    target_size=IMAGE_SIZE,
    class_mode='categorical',
    batch_size=batch_size
)
# Out:
# Found 2032 validated image filenames belonging to 2 classes.

# %%
validation_datagen = ImageDataGenerator(rescale=1./255)
validation_generator = validation_datagen.flow_from_dataframe(
    validate_df, 
    "C:/Users/91809/Desktop/ARKS/05_ARKS_Early-Prediction-of-Autism-Disorder/AutismDataset/train", 
    x_col='filename',
    y_col='category',
    target_size=IMAGE_SIZE,
    class_mode='categorical',
    batch_size=batch_size
)
# Out:
# Found 508 validated image filenames belonging to 2 classes.

# %%
# Fit Model
epochs=3 if FAST_RUN else 50
history = model.fit_generator(
    train_generator, 
    epochs=epochs,
    validation_data=validation_generator,
    validation_steps=total_validate//batch_size,
    steps_per_epoch=total_train//batch_size,
    callbacks=callbacks
)
# Out:
# Epoch 1/50
# C:\Users\91809\AppData\Local\Temp\ipykernel_2040\1475831346.py:3: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   history = model.fit_generator(
# 63/63 [==============================] - ETA: 0s - loss: 1.1297 - accuracy: 0.6155WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 63/63 [==============================] - 14s 159ms/step - loss: 1.1297 - accuracy: 0.6155 - val_loss: 5.7029 - val_accuracy: 0.5063 - lr: 0.0010
# Epoch 2/50
# 63/63 [==============================] - ETA: 0s - loss: 0.8035 - accuracy: 0.6525WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 63/63 [==============================] - 10s 154ms/step - loss: 0.8035 - accuracy: 0.6525 - val_loss: 2.6712 - val_accuracy: 0.5021 - lr: 0.0010
# Epoch 3/50
# 63/63 [==============================] - ETA: 0s - loss: 0.7756 - accuracy: 0.6515WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 63/63 [==============================] - 10s 154ms/step - loss: 0.7756 - accuracy: 0.6515 - val_loss: 2.0171 - val_accuracy: 0.4938 - lr: 0.0010
# Epoch 4/50
# 63/63 [==============================] - ETA: 0s - loss: 0.7141 - accuracy: 0.6410WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 63/63 [==============================] - 10s 154ms/step - loss: 0.7141 - accuracy: 0.6410 - val_loss: 2.6239 - val_accuracy: 0.5063 - lr: 0.0010
# Epoch 5/50
# 63/63 [==============================] - ETA: 0s - loss: 0.6483 - accuracy: 0.6815WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 63/63 [==============================] - 10s 153ms/step - loss: 0.6483 - accuracy: 0.6815 - val_loss: 1.8590 - val_accuracy: 0.5063 - lr: 0.0010
# Epoch 6/50
# 63/63 [==============================] - ETA: 0s - loss: 0.6125 - accuracy: 0.6930WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 63/63 [==============================] - 10s 153ms/step - loss: 0.6125 - accuracy: 0.6930 - val_loss: 2.0969 - val_accuracy: 0.5021 - lr: 0.0010
# Epoch 7/50
# 63/63 [==============================] - ETA: 0s - loss: 0.5748 - accuracy: 0.7200WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 63/63 [==============================] - 10s 152ms/step - loss: 0.5748 - accuracy: 0.7200 - val_loss: 1.9689 - val_accuracy: 0.5000 - lr: 0.0010
# Epoch 8/50
# 63/63 [==============================] - ETA: 0s - loss: 0.5681 - accuracy: 0.7125WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 63/63 [==============================] - 10s 154ms/step - loss: 0.5681 - accuracy: 0.7125 - val_loss: 0.5777 - val_accuracy: 0.6583 - lr: 0.0010
# Epoch 9/50
# 63/63 [==============================] - ETA: 0s - loss: 0.5531 - accuracy: 0.7240WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 63/63 [==============================] - 10s 153ms/step - loss: 0.5531 - accuracy: 0.7240 - val_loss: 1.3888 - val_accuracy: 0.5063 - lr: 0.0010
# Epoch 10/50
# 63/63 [==============================] - ETA: 0s - loss: 0.5501 - accuracy: 0.7210WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 63/63 [==============================] - 10s 152ms/step - loss: 0.5501 - accuracy: 0.7210 - val_loss: 0.7128 - val_accuracy: 0.6083 - lr: 0.0010
# Epoch 11/50
# 63/63 [==============================] - ETA: 0s - loss: 0.5373 - accuracy: 0.7415WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 63/63 [==============================] - 10s 154ms/step - loss: 0.5373 - accuracy: 0.7415 - val_loss: 0.5071 - val_accuracy: 0.7208 - lr: 0.0010
# Epoch 12/50
# 63/63 [==============================] - ETA: 0s - loss: 0.5295 - accuracy: 0.7440WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 63/63 [==============================] - 10s 158ms/step - loss: 0.5295 - accuracy: 0.7440 - val_loss: 0.5862 - val_accuracy: 0.7250 - lr: 0.0010
# Epoch 13/50
# 63/63 [==============================] - ETA: 0s - loss: 0.5268 - accuracy: 0.7385WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 63/63 [==============================] - 10s 162ms/step - loss: 0.5268 - accuracy: 0.7385 - val_loss: 0.5317 - val_accuracy: 0.7292 - lr: 0.0010
# Epoch 14/50
# 63/63 [==============================] - ETA: 0s - loss: 0.5100 - accuracy: 0.7470WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 63/63 [==============================] - 10s 157ms/step - loss: 0.5100 - accuracy: 0.7470 - val_loss: 0.5530 - val_accuracy: 0.7292 - lr: 0.0010
# Epoch 15/50
# 63/63 [==============================] - ETA: 0s - loss: 0.4972 - accuracy: 0.7555WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 63/63 [==============================] - 10s 154ms/step - loss: 0.4972 - accuracy: 0.7555 - val_loss: 0.5326 - val_accuracy: 0.7312 - lr: 0.0010
# Epoch 16/50
# 63/63 [==============================] - ETA: 0s - loss: 0.4948 - accuracy: 0.7620WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 63/63 [==============================] - 10s 153ms/step - loss: 0.4948 - accuracy: 0.7620 - val_loss: 0.5278 - val_accuracy: 0.7583 - lr: 0.0010
# Epoch 17/50
# 63/63 [==============================] - ETA: 0s - loss: 0.4934 - accuracy: 0.7580WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 63/63 [==============================] - 10s 154ms/step - loss: 0.4934 - accuracy: 0.7580 - val_loss: 1.1157 - val_accuracy: 0.5917 - lr: 0.0010
# Epoch 18/50
# 63/63 [==============================] - ETA: 0s - loss: 0.4935 - accuracy: 0.7555WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 63/63 [==============================] - 10s 154ms/step - loss: 0.4935 - accuracy: 0.7555 - val_loss: 0.6156 - val_accuracy: 0.6854 - lr: 0.0010
# Epoch 19/50
# 63/63 [==============================] - ETA: 0s - loss: 0.4735 - accuracy: 0.7795WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 63/63 [==============================] - 10s 154ms/step - loss: 0.4735 - accuracy: 0.7795 - val_loss: 0.5722 - val_accuracy: 0.7375 - lr: 0.0010
# Epoch 20/50
# 63/63 [==============================] - ETA: 0s - loss: 0.4857 - accuracy: 0.7645WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 63/63 [==============================] - 10s 153ms/step - loss: 0.4857 - accuracy: 0.7645 - val_loss: 0.5718 - val_accuracy: 0.7396 - lr: 0.0010
# Epoch 21/50
# 62/63 [============================>.] - ETA: 0s - loss: 0.4758 - accuracy: 0.7737WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 63/63 [==============================] - 10s 154ms/step - loss: 0.4763 - accuracy: 0.7730 - val_loss: 0.7832 - val_accuracy: 0.6313 - lr: 0.0010
# Epoch 22/50
# 63/63 [==============================] - ETA: 0s - loss: 0.4697 - accuracy: 0.7629WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 63/63 [==============================] - 10s 153ms/step - loss: 0.4697 - accuracy: 0.7629 - val_loss: 0.5166 - val_accuracy: 0.7708 - lr: 0.0010
# Epoch 23/50
# 63/63 [==============================] - ETA: 0s - loss: 0.4483 - accuracy: 0.7955WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 63/63 [==============================] - 10s 152ms/step - loss: 0.4483 - accuracy: 0.7955 - val_loss: 0.5856 - val_accuracy: 0.7208 - lr: 0.0010
# Epoch 24/50
# 63/63 [==============================] - ETA: 0s - loss: 0.4686 - accuracy: 0.7830WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 63/63 [==============================] - 10s 154ms/step - loss: 0.4686 - accuracy: 0.7830 - val_loss: 0.4696 - val_accuracy: 0.8021 - lr: 0.0010
# Epoch 25/50
# 63/63 [==============================] - ETA: 0s - loss: 0.4663 - accuracy: 0.7820WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 63/63 [==============================] - 10s 154ms/step - loss: 0.4663 - accuracy: 0.7820 - val_loss: 0.6083 - val_accuracy: 0.7437 - lr: 0.0010
# Epoch 26/50
# 63/63 [==============================] - ETA: 0s - loss: 0.4651 - accuracy: 0.7865WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 63/63 [==============================] - 10s 153ms/step - loss: 0.4651 - accuracy: 0.7865 - val_loss: 0.7518 - val_accuracy: 0.6042 - lr: 0.0010
# Epoch 27/50
# 63/63 [==============================] - ETA: 0s - loss: 0.4507 - accuracy: 0.7825WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 63/63 [==============================] - 10s 151ms/step - loss: 0.4507 - accuracy: 0.7825 - val_loss: 1.8094 - val_accuracy: 0.5729 - lr: 0.0010
# Epoch 28/50
# 63/63 [==============================] - ETA: 0s - loss: 0.4168 - accuracy: 0.8060WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 63/63 [==============================] - 12s 195ms/step - loss: 0.4168 - accuracy: 0.8060 - val_loss: 1.6354 - val_accuracy: 0.5375 - lr: 0.0010
# Epoch 29/50
# 63/63 [==============================] - ETA: 0s - loss: 0.4369 - accuracy: 0.7955WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 63/63 [==============================] - 10s 158ms/step - loss: 0.4369 - accuracy: 0.7955 - val_loss: 0.4816 - val_accuracy: 0.7917 - lr: 0.0010
# Epoch 30/50
# 63/63 [==============================] - ETA: 0s - loss: 0.4482 - accuracy: 0.7955WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 63/63 [==============================] - 10s 157ms/step - loss: 0.4482 - accuracy: 0.7955 - val_loss: 0.5954 - val_accuracy: 0.7229 - lr: 0.0010
# Epoch 31/50
# 63/63 [==============================] - ETA: 0s - loss: 0.4211 - accuracy: 0.8075WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 63/63 [==============================] - 10s 157ms/step - loss: 0.4211 - accuracy: 0.8075 - val_loss: 0.5234 - val_accuracy: 0.7646 - lr: 0.0010
# Epoch 32/50
# 63/63 [==============================] - ETA: 0s - loss: 0.4366 - accuracy: 0.7935WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 63/63 [==============================] - 10s 157ms/step - loss: 0.4366 - accuracy: 0.7935 - val_loss: 0.5579 - val_accuracy: 0.7583 - lr: 0.0010
# Epoch 33/50
# 63/63 [==============================] - ETA: 0s - loss: 0.4162 - accuracy: 0.8080WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 63/63 [==============================] - 10s 158ms/step - loss: 0.4162 - accuracy: 0.8080 - val_loss: 1.0893 - val_accuracy: 0.6104 - lr: 0.0010
# Epoch 34/50
# 63/63 [==============================] - ETA: 0s - loss: 0.4217 - accuracy: 0.8080WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 63/63 [==============================] - 10s 155ms/step - loss: 0.4217 - accuracy: 0.8080 - val_loss: 0.6837 - val_accuracy: 0.6625 - lr: 0.0010
# Epoch 35/50
# 63/63 [==============================] - ETA: 0s - loss: 0.4194 - accuracy: 0.8045WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 63/63 [==============================] - 10s 157ms/step - loss: 0.4194 - accuracy: 0.8045 - val_loss: 0.5134 - val_accuracy: 0.7792 - lr: 0.0010
# Epoch 36/50
# 63/63 [==============================] - ETA: 0s - loss: 0.4215 - accuracy: 0.8040WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 63/63 [==============================] - 10s 156ms/step - loss: 0.4215 - accuracy: 0.8040 - val_loss: 0.5664 - val_accuracy: 0.7729 - lr: 0.0010
# Epoch 37/50
# 63/63 [==============================] - ETA: 0s - loss: 0.4077 - accuracy: 0.8130WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 63/63 [==============================] - 10s 154ms/step - loss: 0.4077 - accuracy: 0.8130 - val_loss: 0.6171 - val_accuracy: 0.7104 - lr: 0.0010
# Epoch 38/50
# 63/63 [==============================] - ETA: 0s - loss: 0.4260 - accuracy: 0.8060WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 63/63 [==============================] - 10s 154ms/step - loss: 0.4260 - accuracy: 0.8060 - val_loss: 1.1598 - val_accuracy: 0.5833 - lr: 0.0010
# Epoch 39/50
# 63/63 [==============================] - ETA: 0s - loss: 0.4157 - accuracy: 0.8165WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 63/63 [==============================] - 10s 154ms/step - loss: 0.4157 - accuracy: 0.8165 - val_loss: 0.5582 - val_accuracy: 0.7750 - lr: 0.0010
# Epoch 40/50
# 63/63 [==============================] - ETA: 0s - loss: 0.3890 - accuracy: 0.8260WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 63/63 [==============================] - 10s 155ms/step - loss: 0.3890 - accuracy: 0.8260 - val_loss: 0.4967 - val_accuracy: 0.7771 - lr: 0.0010
# Epoch 41/50
# 63/63 [==============================] - ETA: 0s - loss: 0.3930 - accuracy: 0.8265WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 63/63 [==============================] - 10s 158ms/step - loss: 0.3930 - accuracy: 0.8265 - val_loss: 0.8228 - val_accuracy: 0.6979 - lr: 0.0010
# Epoch 42/50
# 63/63 [==============================] - ETA: 0s - loss: 0.3923 - accuracy: 0.8215WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 63/63 [==============================] - 10s 158ms/step - loss: 0.3923 - accuracy: 0.8215 - val_loss: 0.6453 - val_accuracy: 0.7375 - lr: 0.0010
# Epoch 43/50
# 63/63 [==============================] - ETA: 0s - loss: 0.3826 - accuracy: 0.8210WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 63/63 [==============================] - 10s 154ms/step - loss: 0.3826 - accuracy: 0.8210 - val_loss: 0.6318 - val_accuracy: 0.7292 - lr: 0.0010
# Epoch 44/50
# 63/63 [==============================] - ETA: 0s - loss: 0.4005 - accuracy: 0.8345WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 63/63 [==============================] - 10s 156ms/step - loss: 0.4005 - accuracy: 0.8345 - val_loss: 0.4911 - val_accuracy: 0.7917 - lr: 0.0010
# Epoch 45/50
# 63/63 [==============================] - ETA: 0s - loss: 0.3816 - accuracy: 0.8320WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 63/63 [==============================] - 10s 155ms/step - loss: 0.3816 - accuracy: 0.8320 - val_loss: 0.6590 - val_accuracy: 0.7146 - lr: 0.0010
# Epoch 46/50
# 63/63 [==============================] - ETA: 0s - loss: 0.3945 - accuracy: 0.8250WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 63/63 [==============================] - 10s 155ms/step - loss: 0.3945 - accuracy: 0.8250 - val_loss: 0.7410 - val_accuracy: 0.7021 - lr: 0.0010
# Epoch 47/50
# 63/63 [==============================] - ETA: 0s - loss: 0.3786 - accuracy: 0.8365WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 63/63 [==============================] - 10s 154ms/step - loss: 0.3786 - accuracy: 0.8365 - val_loss: 0.4844 - val_accuracy: 0.7750 - lr: 0.0010
# Epoch 48/50
# 63/63 [==============================] - ETA: 0s - loss: 0.3661 - accuracy: 0.8375WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 63/63 [==============================] - 10s 160ms/step - loss: 0.3661 - accuracy: 0.8375 - val_loss: 0.6681 - val_accuracy: 0.7354 - lr: 0.0010
# Epoch 49/50
# 63/63 [==============================] - ETA: 0s - loss: 0.3876 - accuracy: 0.8335WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 63/63 [==============================] - 10s 155ms/step - loss: 0.3876 - accuracy: 0.8335 - val_loss: 0.7920 - val_accuracy: 0.7292 - lr: 0.0010
# Epoch 50/50
# 63/63 [==============================] - ETA: 0s - loss: 0.3759 - accuracy: 0.8345WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 63/63 [==============================] - 10s 155ms/step - loss: 0.3759 - accuracy: 0.8345 - val_loss: 0.5212 - val_accuracy: 0.7854 - lr: 0.0010

# %%
model.save_weights("model.h5")

# %%
fig, (ax1, ax2) = plt.subplots(2, 1, figsize=(12, 12))
ax1.plot(history.history['loss'], color='b', label="Training loss")
ax1.plot(history.history['val_loss'], color='r', label="validation loss")
ax1.set_xticks(np.arange(1, epochs, 1))
ax1.set_yticks(np.arange(0, 1, 0.1))

ax2.plot(history.history['accuracy'], color='b', label="Training accuracy")
ax2.plot(history.history['val_accuracy'], color='r',label="Validation accuracy")
ax2.set_xticks(np.arange(1, epochs, 1))

legend = plt.legend(loc='best', shadow=True)
plt.tight_layout()
plt.show()

# %%
# Prepare Testing Data
test_filenames = os.listdir("C:/Users/91809/Desktop/ARKS/05_ARKS_Early-Prediction-of-Autism-Disorder/AutismDataset/test")
test_df = pd.DataFrame({
    'filename': test_filenames
})
nb_samples = test_df.shape[0]

# %%
print(nb_samples)
# Out:
# 300

# %%
# Create Testing Generator
test_gen = ImageDataGenerator(rescale=1./255)
test_generator = test_gen.flow_from_dataframe(
    test_df, 
    "C:/Users/91809/Desktop/ARKS/05_ARKS_Early-Prediction-of-Autism-Disorder/AutismDataset/test", 
    x_col='filename',
    y_col=None,
    class_mode=None,
    target_size=IMAGE_SIZE,
    batch_size=batch_size,
    shuffle=False
)
# Out:
# Found 300 validated image filenames.

# %%
predict = model.predict_generator(test_generator, steps=np.ceil(nb_samples/batch_size))
# Out:
# C:\Users\91809\AppData\Local\Temp\ipykernel_2040\3090721588.py:1: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   predict = model.predict_generator(test_generator, steps=np.ceil(nb_samples/batch_size))

# %%
test_df['category'] = np.argmax(predict, axis=-1)

# %%
label_map = dict((v,k) for k,v in train_generator.class_indices.items())
test_df['category'] = test_df['category'].replace(label_map)

# %%
test_df['category'] = test_df['category'].replace({ 'Autistic': 1, 'Non_Autistic': 0 })

# %%
test_df['category'].value_counts().plot.bar()
# Out:
# <Axes: >

# %%
model.save("newmodel.h5")

# %%
# Define the directory path and image size
directory_path = "C:/Users/91809/Desktop/ARKS/05_ARKS_Early-Prediction-of-Autism-Disorder/AutismDataset/test"
IMAGE_SIZE = (150, 150)  # Adjust the target size as needed

# Assuming you have a DataFrame named 'sample_test'
sample_test = test_df.head(18)

# Create a figure with subplots
plt.figure(figsize=(12, 24))

# Iterate through the DataFrame rows
for index, row in sample_test.iterrows():
    filename = row['filename']
    category = row['category']
    
    # Construct the file path using os.path.join
    file_path = os.path.join(directory_path, filename)

    # Load the image
    img = load_img(file_path, target_size=IMAGE_SIZE)
    
    # Create a subplot
    plt.subplot(6, 3, index % 18 + 1)
    
    # Display the image and label
    plt.imshow(img)
    plt.xlabel(filename + ' (' + str(category) + ')')

# Ensure proper spacing between subplots
plt.tight_layout()

# Show the figure
plt.show()

# %%
submission_df = test_df.copy()
submission_df['id'] = submission_df['filename'].str.split('.').str[0]
submission_df['label'] = submission_df['category']
submission_df.drop(['filename', 'category'], axis=1, inplace=True)
submission_df.to_csv('submission.csv', index=False)

# %%
pd.read_csv("submission.csv")
# Out:
#                id  label
# 0        Autistic      1
# 1        Autistic      1
# 2        Autistic      1
# 3        Autistic      1
# 4        Autistic      1
# ..            ...    ...
# 295  Non_Autistic      0
# 296  Non_Autistic      1
# 297  Non_Autistic      0
# 298  Non_Autistic      0
# 299  Non_Autistic      0
#
# [300 rows x 2 columns]

# %%
plt.figure(figsize=(12, 6))
plt.subplot(1, 2, 1)
plt.plot(history.history['accuracy'], label='Training Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()

plt.tight_layout()
plt.show()
